# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...

# %%
import pandas as pd

df  = pd.read_parquet(r"/workspaces/ML_Model_dirt/data/processed/abt_master.parquet")
df
# Out:
#           data  peso_filtro  classe_filtro  vento_u_mean  vento_v_mean  \
# 0   2025-01-02         0.03            0.0     -0.059713      0.051025
# 1   2025-01-03         0.03            0.0     -0.782145     -0.479666
# 2   2025-01-04         0.01            0.0     -0.404025     -0.412164
# 3   2025-01-05         0.00            0.0     -0.129321     -0.280816
# 4   2025-01-06         0.00            0.0     -0.069696     -0.014938
# ..         ...          ...            ...           ...           ...
# 313 2025-12-24         0.42            NaN     -1.818207     -1.221179
# 314 2025-12-26         0.12            NaN     -2.125458     -1.369889
# 315 2025-12-27         0.15            NaN     -1.797246     -1.138072
# 316 2025-12-28         0.33            NaN     -1.886267     -1.235854
# 317 2025-12-29         0.02            NaN     -1.587555     -0.915985
#
#      vento_vel_mean  vento_vel_max  vento_dir_media  part_9m_max  \
# ...
